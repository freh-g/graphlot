# %%
import graphlot as g
import networkx as nx
import random

# %%
random.seed(123127844)

grafo = g.CreateNetworkFromRandomClasses([20,20,30,],100)
g.plot_degree_distribution_nx(grafo)

# %%
random.seed(123127844)
g.visualize_network(grafo,mode = '2d',node_color_attribute='tipo',legend = 'tipo',cmap='viridis',annotate="name",text_size=10,text_max_distance= 0.02)
